# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

chipo = pd.read_csv(url, sep="\t")

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo.item_price = chipo.item_price.apply(lambda x: float(x.replace("$", "")))
grt_10 = chipo[chipo["item_price"] > 10]["item_name"].nunique()
print(grt_10)
grt_df = grt_10 = chipo[chipo["item_price"] > 10].drop_duplicates()
# Out:
# 31

# %% [markdown]
# ### Step 5. What is the price of each item?
#
# ###### print a data frame with only three columns item_name choice_description and product_price

# %%
display(grt_df[["item_name", "choice_description", "item_price"]])
print(len(grt_df))
# Out:
#                item_name                                 choice_description  \
# 4           Chicken Bowl  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 5           Chicken Bowl  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 7          Steak Burrito  [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 13          Chicken Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# 23       Chicken Burrito  [[Tomatillo-Green Chili Salsa (Medium), Tomati...
# ...                  ...                                                ...
# 4610       Steak Burrito  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4611      Veggie Burrito  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...
# 4617       Steak Burrito  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618       Steak Burrito  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4619  Chicken Salad Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
#
#       item_price
# 4          16.98
# 5          10.98
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
grt_df = grt_df.sort_values(by="item_name")
display(grt_df)
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 3547      1426         1      Barbacoa Bowl
# 2762      1097         1      Barbacoa Bowl
# 4380      1748         1      Barbacoa Bowl
# 2749      1091         1      Barbacoa Bowl
# ...        ...       ...                ...
# 1884       760         1  Veggie Salad Bowl
# 3223      1289         1  Veggie Salad Bowl
# 3889      1559         2  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 738        304         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 3389                                        [Diet Coke]       12.98
# 3547  [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream...       11.75
# 2762  [Tomatillo Red Chili Salsa, [Rice, Fajita Vege...       11.75
# 4380  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.75
# 2749  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...       11.75
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
display(grt_df.sort_values(by="item_price", ascending=False).iloc[0])

grt_df.loc[grt_df["item_price"].idxmax()]["quantity"]
# Out:
# order_id                                      1443
# quantity                                        15
# item_name             Chips and Fresh Tomato Salsa
# choice_description                             NaN
# item_price                                   44.25
# Name: 3598, dtype: object
# np.int64(15)

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
print(chipo[chipo["item_name"] == "Veggie Salad Bowl"].count())
print(chipo[chipo["item_name"] == "Veggie Salad Bowl"]["quantity"].sum())
# Out:
# order_id              18
# quantity              18
# item_name             18
# choice_description    18
# item_price            18
# dtype: int64
# 18

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
chipo[(chipo["item_name"] == "Canned Soda") * (chipo["quantity"] >= 2)].count()
# Out:
# order_id              20
# quantity              20
# item_name             20
# choice_description    20
# item_price            20
# dtype: int64
